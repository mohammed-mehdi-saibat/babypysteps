# %%
import sys;

title = 'Baby Steps'
name = 'Mohammed Mehdi Saibat'
date = 'june 23 2026'

print("Python version:", sys.version) 
print("Python path:", sys.executable)
# Out:
# Python version: 3.12.3 (main, Mar 23 2026, 19:04:32) [GCC 13.3.0]
# Python path: /home/kuklinski/prep-ia-mehdisaibat/.venv/bin/python

# %%
a = 10
b = 3

print(a + b)  
print(a - b)  
print(a * b)   
print(a / b)   
print(a // b)  
print(a % b)   
print(a ** b)

numbers = [10, 25, 3, 47, 8]

for n in numbers:
    print(n)

reponse = """
A virtual environment (venv) is an isolated Python workspace for your project.
It has its own packages that don't interfere with other projects on your machine.
You create it with: python -m venv .venv, and activate it with source .venv/bin/activate.
When active, pip installs packages only inside that folder, not globally.
This way, every project has exactly the dependencies it needs, nothing more.
"""

print(reponse)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000
# 10
# 25
# 3
# 47
# 8
#
# A virtual environment (venv) is an isolated Python workspace for your project.
# It has its own packages that don't interfere with other projects on your machine.
# You create it with: python -m venv .venv, and activate it with source .venv/bin/activate.
# When active, pip installs packages only inside that folder, not globally.
# This way, every project has exactly the dependencies it needs, nothing more.
